# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os

# %%
ls
# Out:
# Annotation/  PNGImages/  PedMasks/  added-object-list.txt*  readme.txt*

# %%
y_dir, X_dir = 'PedMasks/', 'PNGImages/'

# %%
X_paths, y_paths = os.listdir(X_dir), os.listdir(y_dir)

# %%
X = []
for path in X_paths:
    img = mpimg.imread(X_dir + path)
    X.append(img)

# %%
#X = np.vstack(X)
X[12].shape
# Out:
# (411, 723, 3)

# %%
vmax = np.min([x.shape[0] for x in X])
hmax = np.min([x.shape[1] for x in X ])
vmax, hmax
# Out:
# (311, 253)

# %%
X[5].shape
# Out:
# (335, 483, 3)

# %%
img = mpimg.imread('PedMasks/PennPed00039_mask.png')

# %%
plt.imshow(X[5])

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(np.array([[3,1,2],[2,1,5],[2,1,6]]))

# %%
np.unique(img, return_counts = True)
# Out:
# (array([0.        , 0.00392157], dtype=float32), array([170254,  14381]))

# %%
img.sum()
# Out:
# 56.39608

# %%
img[0 < img < .005 ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-3f34b2c6581b> in <module>
# ----> 1 img[0 < img < .005 ]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
img[((img < .005 ) & (img > 0))].sum()
# Out:
# 56.39608
